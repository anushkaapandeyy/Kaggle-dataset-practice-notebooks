# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anthonytherrien/dog-vs-cat")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 360M/360M [00:03<00:00, 124MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anthonytherrien/dog-vs-cat/versions/3

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
base_dir = "/kaggle/input/dog-vs-cat/animals"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% for validation
)

train_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_575/1391775016.py in <cell line: 0>()
#       6 )
#       7
# ----> 8 train_generator = train_datagen.flow_from_directory(
#       9     base_dir,
#      10     target_size=(150, 150),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1134         keep_aspect_ratio=False,
#    1135     ):
# -> 1136         return DirectoryIterator(
#    1137             directory,
#    1138             self,
#
# ...

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),   # helps prevent overfitting
    Dense(1, activation='sigmoid')  # binary output: cat vs dog
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_575/3700795228.py in <cell line: 0>()
#       1 history = model.fit(
# ----> 2     train_generator,
#       3     epochs=10,
#       4     validation_data=val_generator
#       5 )
#
# NameError: name 'train_generator' is not defined

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_575/16536653.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['accuracy'], label='Train Accuracy')
#       4 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       5 plt.legend()
#
# NameError: name 'history' is not defined

# %%
import matplotlib.pyplot as plt

# Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_575/1905197497.py in <cell line: 0>()
#       2
#       3 # Plot Training vs Validation Loss
# ----> 4 plt.plot(history.history['loss'], label='Training Loss')
#       5 plt.plot(history.history['val_loss'], label='Validation Loss')
#       6 plt.title('Model Loss')
#
# NameError: name 'history' is not defined

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Load and preprocess the image
img = image.load_img("SAMPLE.png", target_size=(150,150))   # replace with your file path
img_array = image.img_to_array(img) / 255.0   # normalize
img_array = np.expand_dims(img_array, axis=0) # add batch dimension

# Predict
prediction = model.predict(img_array)

# Interpret result
if prediction[0][0] < 0.5:
    print("Dog 🐶")
else:
    print("Cat 🐱")

# %%
print(train_generator.class_indices)

# %%
img = image.load_img("/sample2.png", target_size=(150,150), color_mode='rgb')

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Load and preprocess the image
img = image.load_img("/sample2.png", target_size=(150,150))   # replace with your file path
img_array = image.img_to_array(img) / 255.0   # normalize
img_array = np.expand_dims(img_array, axis=0) # add batch dimension

# Predict
prediction = model.predict(img_array)

# Interpret result
if prediction[0][0] > 0.5:
    print("Dog 🐶")
else:
    print("Cat 🐱")
